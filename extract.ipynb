# %% [markdown]
# ## Programming for Data Science

# %% [markdown]
# ### **Project 1**
# **Group members:**
# * Ghita Rholi, 20221491@novaims.unl.pt
# * Mariana Ferreira, 20211637@novaims.unl.pt
# * Mariana Neto, 20211527@novaims.unl.pt

# %% [markdown]
# ### Step 3. Feature extraction
#
# Extraction of potential useful features and assessment of features correlation structure.
# - **1.** Totals
#     - **1.1** Total amount of money spent
#     - **1.2** Total amount of purchases
# - **2.** Percentages
#     - **2.1** Percentage of purchases
#     - **2.2** Percentage of the amount of money spent
# - **3.** Child-related features
#     - **3.1** Number of Children
#     - **3.2** Has Child
# - **4.** NaN/Infinite Values
# - **5.** Redundancy analysis
# - **6.** Exporting the dataset
#
# <br>
#
# ##### Importing the necessary libraries

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# Imports spearmanr function from scipy library
from scipy.stats import spearmanr, pearsonr

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <br>

# %% [markdown]
# ##### Importing the dataset from the previous notebook

# %%
data = pd.read_excel("after_preprocess.xlsx", index_col = "ID")

# %% [markdown]
# <br>

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# Feature extraction is the process of defining a set of (new) features, which are a linear combination of the existing data.
# By eliminating redundant data from a dataset, feature extraction helps to effectively represent crucial information for future analyses.
#
# Having familiarized ourselves with the dataset in the previous steps, it is now easier to look at the data and identify new possible variables that might have a good impact on the model. To do that we can start by looking at the dataset and visualzing all the columns one more time, using the ``.T`` method on the 'data'.

# %%
data.T
# Out:
# ID                      5314        2493        4931     1100        7224   \
# Education          Graduation  Graduation  Graduation   Master  Graduation
# Age                        67          52          41       58          41
# CustomerDays             1750        1613        1708     1379        1464
# MaritalStatus          Single     Married      Single   Single     Married
# NKids                       0           0           0        1           0
# NTeens                      1           1           0        2           0
# Income                40689.0     61286.0    157146.0  41275.0     31353.0
# MntWines                  270         356           1       24          10
# MntFruits                   3           0           0        4           0
# MntMeatProducts            27         107        1725       22          10
# MntFishProducts            39          19           2        0           3
# MntSweetProducts            6           9           1        2           1
# MntGoldProds               99         117           1        9           7
# Complain                    0           0           0        0           0
# Recency                    69          34          13       33          24
# NDealsPurchases             7           2           0        4           2
# NWebPurchases               7           7           0        3           1
# NCatalogPurchases           1           1          28        1           1
# NStorePurchases             5           8           0        3           2
# NWebVisitsMonth             8           5           1        5           8
# Response1                   0           0           0        0           0
# Response2                   0           0           0        0           0
# Response3                   0           0           0        0           0
# Response4                   0           0           0        0           0
# Response5                   0           0           0        0           0
# Response                    0           0           0        0           0
#
# ID                   2795            5555        10277    624         9499   \
# Education           Master      Graduation  Graduation   Master  Graduation
# Age                     60              43          57       34          64
# CustomerDays          1645            1424        1775     1878        1700
# MaritalStatus       Single        Divorced      Single   Single     Married
# NKids                    2               0           0        0           1
# NTeens                   1               0           1        0           2
# Income             30523.0        153924.0     30081.0  18890.0     93404.0
# MntWines                 5               0          36        6        1279
# MntFruits                0               0           0        4          15
# MntMeatProducts          3               0           2        1         287
# MntFishProducts          0               0           0        7          20
# MntSweetProducts         0               0           0        2           0
# MntGoldProds             5               1           4       15          15
# Complain                 0               0           0        0           0
# Recency                  0  Not Applicable          27        5          97
# NDealsPurchases          1               0           1        1           3
# NWebPurchases            1               0           1        0           3
# NCatalogPurchases        0               0           0        1           4
# NStorePurchases          2               0           3        2           7
# NWebVisitsMonth          7               0           7        6           5
# Response1                0               0           0        0           0
# Response2                0               0           0        0           0
# Response3                0               0           0        1           0
# Response4                0               0           0        0           1
# Response5                0               0           0        0           1
# Response                 0               0           0        1           0
#
# ID                 ...       9937     2461     9606        7214        6424   \
# Education          ...  Graduation   Master      PhD  Graduation  Graduation
# Age                ...          39       63       53          61          41
# CustomerDays       ...        1460     1475     1588        1641        1432
# MaritalStatus      ...      Single   Single  Married     Married      Single
# NKids              ...           0        1        0           0           1
# NTeens             ...           0        1        0           0           0
# Income             ...     70337.0  51124.0  69969.0     62187.0     33178.0
# MntWines           ...         187       26      882         792          12
# MntFruits          ...          81        1       29           0           6
# MntMeatProducts    ...         149       11      514         275           2
# MntFishProducts    ...          25        0       38          45          11
# MntSweetProducts   ...          43        1       29          45           2
# MntGoldProds       ...          91        4       44         126          16
# Complain           ...           0        0        0           0           0
# Recency            ...          75       79       64          49           9
# NDealsPurchases    ...           1        2        1           1           1
# NWebPurchases      ...           2        1        4           4           1
# NCatalogPurchases  ...           2        0        2           8           0
# NStorePurchases    ...          12        3        6           5           3
# NWebVisitsMonth    ...           1        3        3           3           4
# Response1          ...           0        0        1           0           0
# Response2          ...           0        0        0           0           0
# Response3          ...           0        0        0           0           0
# Response4          ...           0        0        0           0           0
# Response5          ...           0        0        1           0           0
# Response           ...           0        0        1           0           0
#
# ID                      3887     5181        5758        9729     10478
# Education          Graduation    Basic  Graduation  Graduation      PhD
# Age                        48       36          36          63       68
# CustomerDays             1877     1748        1448        1674     1922
# MaritalStatus          Single   Single     Married       Widow  Married
# NKids                       1        1           0           1        1
# NTeens                      0        0           0           1        1
# Income                27242.0  24367.0     65169.0     58275.0  55517.0
# MntWines                    3        2        1074         189      483
# MntFruits                  17        4           0          10        0
# MntMeatProducts            26        2          69         253      108
# MntFishProducts            20        0           0          56        0
# MntSweetProducts            1       11           0          43        6
# MntGoldProds               39        5          46          64       36
# Complain                    0        0           0           0        0
# Recency                     2       58          23          48       53
# NDealsPurchases             2        1           1           6        5
# NWebPurchases               2        1          10           8       11
# NCatalogPurchases           0        0           4           2        1
# NStorePurchases             3        2          13           7        6
# NWebVisitsMonth             9        9           6           7        9
# Response1                   0        0           1           0        0
# Response2                   0        0           1           0        0
# Response3                   0        0           1           0        0
# Response4                   0        0           0           0        0
# Response5                   0        0           1           0        0
# Response                    1        0           1           0        1
#
# [26 rows x 2065 columns]

# %% [markdown]
# Prior to generating the new columns, we create a function (``get_columns_index()``) that will be useful for visual purposes. That is, this function will return either a text where the index of a given column (or a list of columns) is described or it will return the index itself. If the parameter index_describe is 'yes', then the function will print the column name and the corresponding index, and if it is 'no', the function will retun the index value.
# This function is defined in the code below.

# %%
def get_columns_index(column_names, index_described):
    # Column names can either be a list or a string
    # If column_names is a list
    if isinstance(column_names, list):
        # It uses all the column names in the list
        for column_name in column_names:
            # It gets the index of the columns corresponding to the names
            index = data.columns.get_loc(column_name)
            # If it is wanted the index to be described, index_describe is equal to yes
            if index_described == 'yes':
                # It prints the column name and the associated index
                print(f'Index of column named {column_name} is: {index}')
            # If it is not wanted the index to be described, index_describe is equal to no
            elif index_described == 'no':
                return index
            # If the value of index_described is not valid, nothing happens
            else:
                return
    # If column_names is a string
    elif isinstance(column_names, str):
        # It gets the index of the column corresponding to the name
        index = data.columns.get_loc(column_names)
        if index_described == 'yes':
            # It prints the column name and the associated index
            print(f'Index of column named {column_names} is: {index}')
            # If it is not wanted the index to be described, index_describe is equal to no
        elif index_described == 'no':
            return index
            # If the value of index_described is not valid, nothing happens
        else:
            return
    # If column_names is neither a string nor a list, nothing happens
    else:
        return

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## **1.** Totals
#
# The Totals features correspond to the sum of all the features within a certain group. This linear combination allows for a more accurate interpretation of an individual's behavior, since it provides the overall behavior in a category (Which, in this case, will be purchases and money spent).
#
# To automatize the extraction of such variables, a function (``total()``) is created. This function is defined in the code below.

# %%
def total(columns, suffix, index):
    total = 0
    for column in columns:
        total += data[column]
    data.insert(loc=index, column=f"Total{suffix}", value = total)

# %% [markdown]
# <br>

# %% [markdown]
# #### **1.1** Total amount of money spent
#
# The Total amount of money spent (TotalMnt), corresponding to the sum of the columns MntFishProducts, MntMeatProducts, MntFruits, MntSweetProducts, and MntWines, is an important measurement. This is due to the fact that, in this particular model, it may be relevant to know which individuals spent the most and the least money within the company.

# %% [markdown]
# Just before creating this feature, the function ``get_columns_index()`` is used so that it is known the indexes of the columns used to generate the respective feature. With that information, it is possible to place the new feature next to the ones it is related to.

# %%
column_names = ["MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts"]
get_columns_index(column_names, 'yes')
# Out:
# Index of column named MntWines is: 7
# Index of column named MntFruits is: 8
# Index of column named MntMeatProducts is: 9
# Index of column named MntFishProducts is: 10
# Index of column named MntSweetProducts is: 11

# %% [markdown]
# The code above enabled the acknowlegment that the last column related to the amount of money spent on products is in the index 12, therefore, the feature TotalMnt may be placed in index 13. In the cell below, the new column is inserted in the data, in index 13, with the suffix 'Mnt' and considering all the column names in the column_names list from the code above.
#
# The data is being displayed, transposed, so that we can check if the position is correct.

# %%
total(column_names, 'Mnt', 13)
data.T
# Out:
# ID                      5314        2493        4931     1100        7224   \
# Education          Graduation  Graduation  Graduation   Master  Graduation
# Age                        67          52          41       58          41
# CustomerDays             1750        1613        1708     1379        1464
# MaritalStatus          Single     Married      Single   Single     Married
# NKids                       0           0           0        1           0
# NTeens                      1           1           0        2           0
# Income                40689.0     61286.0    157146.0  41275.0     31353.0
# MntWines                  270         356           1       24          10
# MntFruits                   3           0           0        4           0
# MntMeatProducts            27         107        1725       22          10
# MntFishProducts            39          19           2        0           3
# MntSweetProducts            6           9           1        2           1
# MntGoldProds               99         117           1        9           7
# TotalMnt                  345         491        1729       52          24
# Complain                    0           0           0        0           0
# Recency                    69          34          13       33          24
# NDealsPurchases             7           2           0        4           2
# NWebPurchases               7           7           0        3           1
# NCatalogPurchases           1           1          28        1           1
# NStorePurchases             5           8           0        3           2
# NWebVisitsMonth             8           5           1        5           8
# Response1                   0           0           0        0           0
# Response2                   0           0           0        0           0
# Response3                   0           0           0        0           0
# Response4                   0           0           0        0           0
# Response5                   0           0           0        0           0
# Response                    0           0           0        0           0
#
# ID                   2795            5555        10277    624         9499   \
# Education           Master      Graduation  Graduation   Master  Graduation
# Age                     60              43          57       34          64
# CustomerDays          1645            1424        1775     1878        1700
# MaritalStatus       Single        Divorced      Single   Single     Married
# NKids                    2               0           0        0           1
# NTeens                   1               0           1        0           2
# Income             30523.0        153924.0     30081.0  18890.0     93404.0
# MntWines                 5               0          36        6        1279
# MntFruits                0               0           0        4          15
# MntMeatProducts          3               0           2        1         287
# MntFishProducts          0               0           0        7          20
# MntSweetProducts         0               0           0        2           0
# MntGoldProds             5               1           4       15          15
# TotalMnt                 8               0          38       20        1601
# Complain                 0               0           0        0           0
# Recency                  0  Not Applicable          27        5          97
# NDealsPurchases          1               0           1        1           3
# NWebPurchases            1               0           1        0           3
# NCatalogPurchases        0               0           0        1           4
# NStorePurchases          2               0           3        2           7
# NWebVisitsMonth          7               0           7        6           5
# Response1                0               0           0        0           0
# Response2                0               0           0        0           0
# Response3                0               0           0        1           0
# Response4                0               0           0        0           1
# Response5                0               0           0        0           1
# Response                 0               0           0        1           0
#
# ID                 ...       9937     2461     9606        7214        6424   \
# Education          ...  Graduation   Master      PhD  Graduation  Graduation
# Age                ...          39       63       53          61          41
# CustomerDays       ...        1460     1475     1588        1641        1432
# MaritalStatus      ...      Single   Single  Married     Married      Single
# NKids              ...           0        1        0           0           1
# NTeens             ...           0        1        0           0           0
# Income             ...     70337.0  51124.0  69969.0     62187.0     33178.0
# MntWines           ...         187       26      882         792          12
# MntFruits          ...          81        1       29           0           6
# MntMeatProducts    ...         149       11      514         275           2
# MntFishProducts    ...          25        0       38          45          11
# MntSweetProducts   ...          43        1       29          45           2
# MntGoldProds       ...          91        4       44         126          16
# TotalMnt           ...         485       39     1492        1157          33
# Complain           ...           0        0        0           0           0
# Recency            ...          75       79       64          49           9
# NDealsPurchases    ...           1        2        1           1           1
# NWebPurchases      ...           2        1        4           4           1
# NCatalogPurchases  ...           2        0        2           8           0
# NStorePurchases    ...          12        3        6           5           3
# NWebVisitsMonth    ...           1        3        3           3           4
# Response1          ...           0        0        1           0           0
# Response2          ...           0        0        0           0           0
# Response3          ...           0        0        0           0           0
# Response4          ...           0        0        0           0           0
# Response5          ...           0        0        1           0           0
# Response           ...           0        0        1           0           0
#
# ID                      3887     5181        5758        9729     10478
# Education          Graduation    Basic  Graduation  Graduation      PhD
# Age                        48       36          36          63       68
# CustomerDays             1877     1748        1448        1674     1922
# MaritalStatus          Single   Single     Married       Widow  Married
# NKids                       1        1           0           1        1
# NTeens                      0        0           0           1        1
# Income                27242.0  24367.0     65169.0     58275.0  55517.0
# MntWines                    3        2        1074         189      483
# MntFruits                  17        4           0          10        0
# MntMeatProducts            26        2          69         253      108
# MntFishProducts            20        0           0          56        0
# MntSweetProducts            1       11           0          43        6
# MntGoldProds               39        5          46          64       36
# TotalMnt                   67       19        1143         551      597
# Complain                    0        0           0           0        0
# Recency                     2       58          23          48       53
# NDealsPurchases             2        1           1           6        5
# NWebPurchases               2        1          10           8       11
# NCatalogPurchases           0        0           4           2        1
# NStorePurchases             3        2          13           7        6
# NWebVisitsMonth             9        9           6           7        9
# Response1                   0        0           1           0        0
# Response2                   0        0           1           0        0
# Response3                   0        0           1           0        0
# Response4                   0        0           0           0        0
# Response5                   0        0           1           0        0
# Response                    1        0           1           0        1
#
# [27 rows x 2065 columns]

# %% [markdown]
# Through the visualization of the table above, it is observed that the new column (TotalMnt) is in the intended position.

# %% [markdown]
# The ``.filter()`` function subsets the dataframe columns according to the word "Mnt", in order to get a better look at the values related to wines, fruits, meat, fish, sweet, gold products and the total amount spent.

# %%
data.filter(regex="Mnt",axis=1)
# Out:
#        MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# ID
# 5314        270          3               27               39
# 2493        356          0              107               19
# 4931          1          0             1725                2
# 1100         24          4               22                0
# 7224         10          0               10                3
# ...         ...        ...              ...              ...
# 3887          3         17               26               20
# 5181          2          4                2                0
# 5758       1074          0               69                0
# 9729        189         10              253               56
# 10478       483          0              108                0
#
#        MntSweetProducts  MntGoldProds  TotalMnt
# ID
# 5314                  6            99       345
# 2493                  9           117       491
# 4931                  1             1      1729
# 1100                  2             9        52
# 7224                  1             7        24
# ...                 ...           ...       ...
# 3887                  1            39        67
# 5181                 11             5        19
# 5758                  0            46      1143
# 9729                 43            64       551
# 10478                 6            36       597
#
# [2065 rows x 7 columns]

# %% [markdown]
# With the table above it is possible to observe that the TotalMnt column was correctly implemented.

# %% [markdown]
# <br>

# %% [markdown]
# #### **1.2** Total amount of purchases
#
# The Total amount of Purchases (TotalPurchases) corresponds to the sum of the amount of purchases made using the companies' website (NWebPurchases), the catalog (NCatalogPurchases) and in the store (NStorePurchases). This feature may help understand which customers have purchased the most and the least.
#
# The function below is used to get the indexes of the columns NWebPurchases, NCatalogPurchases and NStorePurchases.

# %%
column_names = ["NWebPurchases","NCatalogPurchases","NStorePurchases"]
get_columns_index(column_names, 'yes')
# Out:
# Index of column named NWebPurchases is: 17
# Index of column named NCatalogPurchases is: 18
# Index of column named NStorePurchases is: 19

# %% [markdown]
# The last index given by the function is 19. Therefore, for the new feature to be placed next to the ones it is related to, it will be stored at index 20.

# %%
total(column_names, 'Purchases', 20)
data.T
# Out:
# ID                      5314        2493        4931     1100        7224   \
# Education          Graduation  Graduation  Graduation   Master  Graduation
# Age                        67          52          41       58          41
# CustomerDays             1750        1613        1708     1379        1464
# MaritalStatus          Single     Married      Single   Single     Married
# NKids                       0           0           0        1           0
# NTeens                      1           1           0        2           0
# Income                40689.0     61286.0    157146.0  41275.0     31353.0
# MntWines                  270         356           1       24          10
# MntFruits                   3           0           0        4           0
# MntMeatProducts            27         107        1725       22          10
# MntFishProducts            39          19           2        0           3
# MntSweetProducts            6           9           1        2           1
# MntGoldProds               99         117           1        9           7
# TotalMnt                  345         491        1729       52          24
# Complain                    0           0           0        0           0
# Recency                    69          34          13       33          24
# NDealsPurchases             7           2           0        4           2
# NWebPurchases               7           7           0        3           1
# NCatalogPurchases           1           1          28        1           1
# NStorePurchases             5           8           0        3           2
# TotalPurchases             13          16          28        7           4
# NWebVisitsMonth             8           5           1        5           8
# Response1                   0           0           0        0           0
# Response2                   0           0           0        0           0
# Response3                   0           0           0        0           0
# Response4                   0           0           0        0           0
# Response5                   0           0           0        0           0
# Response                    0           0           0        0           0
#
# ID                   2795            5555        10277    624         9499   \
# Education           Master      Graduation  Graduation   Master  Graduation
# Age                     60              43          57       34          64
# CustomerDays          1645            1424        1775     1878        1700
# MaritalStatus       Single        Divorced      Single   Single     Married
# NKids                    2               0           0        0           1
# NTeens                   1               0           1        0           2
# Income             30523.0        153924.0     30081.0  18890.0     93404.0
# MntWines                 5               0          36        6        1279
# MntFruits                0               0           0        4          15
# MntMeatProducts          3               0           2        1         287
# MntFishProducts          0               0           0        7          20
# MntSweetProducts         0               0           0        2           0
# MntGoldProds             5               1           4       15          15
# TotalMnt                 8               0          38       20        1601
# Complain                 0               0           0        0           0
# Recency                  0  Not Applicable          27        5          97
# NDealsPurchases          1               0           1        1           3
# NWebPurchases            1               0           1        0           3
# NCatalogPurchases        0               0           0        1           4
# NStorePurchases          2               0           3        2           7
# TotalPurchases           3               0           4        3          14
# NWebVisitsMonth          7               0           7        6           5
# Response1                0               0           0        0           0
# Response2                0               0           0        0           0
# Response3                0               0           0        1           0
# Response4                0               0           0        0           1
# Response5                0               0           0        0           1
# Response                 0               0           0        1           0
#
# ID                 ...       9937     2461     9606        7214        6424   \
# Education          ...  Graduation   Master      PhD  Graduation  Graduation
# Age                ...          39       63       53          61          41
# CustomerDays       ...        1460     1475     1588        1641        1432
# MaritalStatus      ...      Single   Single  Married     Married      Single
# NKids              ...           0        1        0           0           1
# NTeens             ...           0        1        0           0           0
# Income             ...     70337.0  51124.0  69969.0     62187.0     33178.0
# MntWines           ...         187       26      882         792          12
# MntFruits          ...          81        1       29           0           6
# MntMeatProducts    ...         149       11      514         275           2
# MntFishProducts    ...          25        0       38          45          11
# MntSweetProducts   ...          43        1       29          45           2
# MntGoldProds       ...          91        4       44         126          16
# TotalMnt           ...         485       39     1492        1157          33
# Complain           ...           0        0        0           0           0
# Recency            ...          75       79       64          49           9
# NDealsPurchases    ...           1        2        1           1           1
# NWebPurchases      ...           2        1        4           4           1
# NCatalogPurchases  ...           2        0        2           8           0
# NStorePurchases    ...          12        3        6           5           3
# TotalPurchases     ...          16        4       12          17           4
# NWebVisitsMonth    ...           1        3        3           3           4
# Response1          ...           0        0        1           0           0
# Response2          ...           0        0        0           0           0
# Response3          ...           0        0        0           0           0
# Response4          ...           0        0        0           0           0
# Response5          ...           0        0        1           0           0
# Response           ...           0        0        1           0           0
#
# ID                      3887     5181        5758        9729     10478
# Education          Graduation    Basic  Graduation  Graduation      PhD
# Age                        48       36          36          63       68
# CustomerDays             1877     1748        1448        1674     1922
# MaritalStatus          Single   Single     Married       Widow  Married
# NKids                       1        1           0           1        1
# NTeens                      0        0           0           1        1
# Income                27242.0  24367.0     65169.0     58275.0  55517.0
# MntWines                    3        2        1074         189      483
# MntFruits                  17        4           0          10        0
# MntMeatProducts            26        2          69         253      108
# MntFishProducts            20        0           0          56        0
# MntSweetProducts            1       11           0          43        6
# MntGoldProds               39        5          46          64       36
# TotalMnt                   67       19        1143         551      597
# Complain                    0        0           0           0        0
# Recency                     2       58          23          48       53
# NDealsPurchases             2        1           1           6        5
# NWebPurchases               2        1          10           8       11
# NCatalogPurchases           0        0           4           2        1
# NStorePurchases             3        2          13           7        6
# TotalPurchases              5        3          27          17       18
# NWebVisitsMonth             9        9           6           7        9
# Response1                   0        0           1           0        0
# Response2                   0        0           1           0        0
# Response3                   0        0           1           0        0
# Response4                   0        0           0           0        0
# Response5                   0        0           1           0        0
# Response                    1        0           1           0        1
#
# [28 rows x 2065 columns]

# %% [markdown]
# <br>
#
# We can use, again, the ``.filter()`` method to get a better look at the features related to purchases.

# %%
data.filter(regex="Purchases",axis=1)
# Out:
#        NDealsPurchases  NWebPurchases  NCatalogPurchases  NStorePurchases  \
# ID
# 5314                 7              7                  1                5
# 2493                 2              7                  1                8
# 4931                 0              0                 28                0
# 1100                 4              3                  1                3
# 7224                 2              1                  1                2
# ...                ...            ...                ...              ...
# 3887                 2              2                  0                3
# 5181                 1              1                  0                2
# 5758                 1             10                  4               13
# 9729                 6              8                  2                7
# 10478                5             11                  1                6
#
#        TotalPurchases
# ID
# 5314               13
# 2493               16
# 4931               28
# 1100                7
# 7224                4
# ...               ...
# 3887                5
# 5181                3
# 5758               27
# 9729               17
# 10478              18
#
# [2065 rows x 5 columns]

# %% [markdown]
# With the table above it is possible to observe that the TotalPurchases column was correctly implemented.

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## **2.** Percentages
#
# Percentages are a commonly used way to represent data. It is easy to understand in any context, especially in comparison to mere numbers that might not convey anything to potential readers. Thus, it could be beneficial to create new features that will represent some useful percentage for the model.
#
# To automatize the creation of this new features, it is first defined a function (``percentages()``) which is defined in the code below.

# %%
def percentages(numerator, denominator, index, suffix):
    percentages = (data[numerator] / data[denominator])*100
    data.insert(loc = index, column= 'P' + suffix, value = percentages)

# %% [markdown]
# <br>
#
# #### **2.1** Percentage of purchases
# An interesting feature that can help understand which purchasing channel is most appealing to a customer is the percentage of purchases. This will allow insight on the purchases made through the catalog, the company's website, and the store in such a way as to recognize patterns that indicate a customer's preference (purchasing from the store, website, or catalog).
#
# <br>
#
# **2.1.1** Percentage of catalog purchases

# %% [markdown]
# The percentage of catalog purchases is the proportion of the amount of purchases made using a catalog, by the total number of purchases made using the three different channels.
#
# In the next cell it is executed the function that returns the index of the column NCatalogPurchases.

# %%
get_columns_index("NCatalogPurchases", 'yes')
# Out:
# Index of column named NCatalogPurchases is: 18

# %% [markdown]
# NCatalogPurchases is at index 18, therefore, the feature PCatalogPurchases will be store at index 19.

# %% [markdown]
# The following code creates a feature with the mentioned percentage of NCatalogPurchases in TotalPurchases, which is placed in index 19.

# %%
percentages('NCatalogPurchases', 'TotalPurchases', 19, 'CatalogPurchases')
data.T
# Out:
# ID                      5314        2493        4931       1100        7224   \
# Education          Graduation  Graduation  Graduation     Master  Graduation
# Age                        67          52          41         58          41
# CustomerDays             1750        1613        1708       1379        1464
# MaritalStatus          Single     Married      Single     Single     Married
# NKids                       0           0           0          1           0
# NTeens                      1           1           0          2           0
# Income                40689.0     61286.0    157146.0    41275.0     31353.0
# MntWines                  270         356           1         24          10
# MntFruits                   3           0           0          4           0
# MntMeatProducts            27         107        1725         22          10
# MntFishProducts            39          19           2          0           3
# MntSweetProducts            6           9           1          2           1
# MntGoldProds               99         117           1          9           7
# TotalMnt                  345         491        1729         52          24
# Complain                    0           0           0          0           0
# Recency                    69          34          13         33          24
# NDealsPurchases             7           2           0          4           2
# NWebPurchases               7           7           0          3           1
# NCatalogPurchases           1           1          28          1           1
# PCatalogPurchases    7.692308        6.25       100.0  14.285714        25.0
# NStorePurchases             5           8           0          3           2
# TotalPurchases             13          16          28          7           4
# NWebVisitsMonth             8           5           1          5           8
# Response1                   0           0           0          0           0
# Response2                   0           0           0          0           0
# Response3                   0           0           0          0           0
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           0
# Response                    0           0           0          0           0
#
# ID                   2795            5555        10277      624         9499   \
# Education           Master      Graduation  Graduation     Master  Graduation
# Age                     60              43          57         34          64
# CustomerDays          1645            1424        1775       1878        1700
# MaritalStatus       Single        Divorced      Single     Single     Married
# NKids                    2               0           0          0           1
# NTeens                   1               0           1          0           2
# Income             30523.0        153924.0     30081.0    18890.0     93404.0
# MntWines                 5               0          36          6        1279
# MntFruits                0               0           0          4          15
# MntMeatProducts          3               0           2          1         287
# MntFishProducts          0               0           0          7          20
# MntSweetProducts         0               0           0          2           0
# MntGoldProds             5               1           4         15          15
# TotalMnt                 8               0          38         20        1601
# Complain                 0               0           0          0           0
# Recency                  0  Not Applicable          27          5          97
# NDealsPurchases          1               0           1          1           3
# NWebPurchases            1               0           1          0           3
# NCatalogPurchases        0               0           0          1           4
# PCatalogPurchases      0.0             NaN         0.0  33.333333   28.571429
# NStorePurchases          2               0           3          2           7
# TotalPurchases           3               0           4          3          14
# NWebVisitsMonth          7               0           7          6           5
# Response1                0               0           0          0           0
# Response2                0               0           0          0           0
# Response3                0               0           0          1           0
# Response4                0               0           0          0           1
# Response5                0               0           0          0           1
# Response                 0               0           0          1           0
#
# ID                 ...       9937     2461       9606        7214   \
# Education          ...  Graduation   Master        PhD  Graduation
# Age                ...          39       63         53          61
# CustomerDays       ...        1460     1475       1588        1641
# MaritalStatus      ...      Single   Single    Married     Married
# NKids              ...           0        1          0           0
# NTeens             ...           0        1          0           0
# Income             ...     70337.0  51124.0    69969.0     62187.0
# MntWines           ...         187       26        882         792
# MntFruits          ...          81        1         29           0
# MntMeatProducts    ...         149       11        514         275
# MntFishProducts    ...          25        0         38          45
# MntSweetProducts   ...          43        1         29          45
# MntGoldProds       ...          91        4         44         126
# TotalMnt           ...         485       39       1492        1157
# Complain           ...           0        0          0           0
# Recency            ...          75       79         64          49
# NDealsPurchases    ...           1        2          1           1
# NWebPurchases      ...           2        1          4           4
# NCatalogPurchases  ...           2        0          2           8
# PCatalogPurchases  ...        12.5      0.0  16.666667   47.058824
# NStorePurchases    ...          12        3          6           5
# TotalPurchases     ...          16        4         12          17
# NWebVisitsMonth    ...           1        3          3           3
# Response1          ...           0        0          1           0
# Response2          ...           0        0          0           0
# Response3          ...           0        0          0           0
# Response4          ...           0        0          0           0
# Response5          ...           0        0          1           0
# Response           ...           0        0          1           0
#
# ID                      6424        3887     5181        5758        9729   \
# Education          Graduation  Graduation    Basic  Graduation  Graduation
# Age                        41          48       36          36          63
# CustomerDays             1432        1877     1748        1448        1674
# MaritalStatus          Single      Single   Single     Married       Widow
# NKids                       1           1        1           0           1
# NTeens                      0           0        0           0           1
# Income                33178.0     27242.0  24367.0     65169.0     58275.0
# MntWines                   12           3        2        1074         189
# MntFruits                   6          17        4           0          10
# MntMeatProducts             2          26        2          69         253
# MntFishProducts            11          20        0           0          56
# MntSweetProducts            2           1       11           0          43
# MntGoldProds               16          39        5          46          64
# TotalMnt                   33          67       19        1143         551
# Complain                    0           0        0           0           0
# Recency                     9           2       58          23          48
# NDealsPurchases             1           2        1           1           6
# NWebPurchases               1           2        1          10           8
# NCatalogPurchases           0           0        0           4           2
# PCatalogPurchases         0.0         0.0      0.0   14.814815   11.764706
# NStorePurchases             3           3        2          13           7
# TotalPurchases              4           5        3          27          17
# NWebVisitsMonth             4           9        9           6           7
# Response1                   0           0        0           1           0
# Response2                   0           0        0           1           0
# Response3                   0           0        0           1           0
# Response4                   0           0        0           0           0
# Response5                   0           0        0           1           0
# Response                    0           1        0           1           0
#
# ID                    10478
# Education               PhD
# Age                      68
# CustomerDays           1922
# MaritalStatus       Married
# NKids                     1
# NTeens                    1
# Income              55517.0
# MntWines                483
# MntFruits                 0
# MntMeatProducts         108
# MntFishProducts           0
# MntSweetProducts          6
# MntGoldProds             36
# TotalMnt                597
# Complain                  0
# Recency                  53
# NDealsPurchases           5
# NWebPurchases            11
# NCatalogPurchases         1
# PCatalogPurchases  5.555556
# NStorePurchases           6
# TotalPurchases           18
# NWebVisitsMonth           9
# Response1                 0
# Response2                 0
# Response3                 0
# Response4                 0
# Response5                 0
# Response                  1
#
# [29 rows x 2065 columns]

# %% [markdown]
# This ``filter()`` method generates a dataframe that exposes the relative and absolute values of purchases made using a catalog.

# %%
data.filter(regex='NCatalogPurchases|PCatalogPurchases',axis=1)
# Out:
#        NCatalogPurchases  PCatalogPurchases
# ID
# 5314                   1           7.692308
# 2493                   1           6.250000
# 4931                  28         100.000000
# 1100                   1          14.285714
# 7224                   1          25.000000
# ...                  ...                ...
# 3887                   0           0.000000
# 5181                   0           0.000000
# 5758                   4          14.814815
# 9729                   2          11.764706
# 10478                  1           5.555556
#
# [2065 rows x 2 columns]

# %% [markdown]
# <br>

# %% [markdown]
# **2.1.2** Percentage of Web purchases

# %% [markdown]
# The percentage of Web purchases is the proportion of the amount of purchases made using the Website, by the total number of purchases made using the three different channels.
#
# In the next cell it is executed the function that returns the index of the column NWebPurchases.

# %%
get_columns_index("NWebPurchases", 'yes')
# Out:
# Index of column named NWebPurchases is: 17

# %% [markdown]
# NWebPurchases is at index 17, therefore, the feature PWebPurchases will be store at index 18.

# %% [markdown]
# The following code creates a feature with the mentioned percentage of NWebPurchases in TotalPurchases, which is placed in index 18.

# %%
percentages('NWebPurchases', 'TotalPurchases', 18, 'WebPurchases')
data.T
# Out:
# ID                      5314        2493        4931       1100        7224   \
# Education          Graduation  Graduation  Graduation     Master  Graduation
# Age                        67          52          41         58          41
# CustomerDays             1750        1613        1708       1379        1464
# MaritalStatus          Single     Married      Single     Single     Married
# NKids                       0           0           0          1           0
# NTeens                      1           1           0          2           0
# Income                40689.0     61286.0    157146.0    41275.0     31353.0
# MntWines                  270         356           1         24          10
# MntFruits                   3           0           0          4           0
# MntMeatProducts            27         107        1725         22          10
# MntFishProducts            39          19           2          0           3
# MntSweetProducts            6           9           1          2           1
# MntGoldProds               99         117           1          9           7
# TotalMnt                  345         491        1729         52          24
# Complain                    0           0           0          0           0
# Recency                    69          34          13         33          24
# NDealsPurchases             7           2           0          4           2
# NWebPurchases               7           7           0          3           1
# PWebPurchases       53.846154       43.75         0.0  42.857143        25.0
# NCatalogPurchases           1           1          28          1           1
# PCatalogPurchases    7.692308        6.25       100.0  14.285714        25.0
# NStorePurchases             5           8           0          3           2
# TotalPurchases             13          16          28          7           4
# NWebVisitsMonth             8           5           1          5           8
# Response1                   0           0           0          0           0
# Response2                   0           0           0          0           0
# Response3                   0           0           0          0           0
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           0
# Response                    0           0           0          0           0
#
# ID                     2795            5555        10277      624    \
# Education             Master      Graduation  Graduation     Master
# Age                       60              43          57         34
# CustomerDays            1645            1424        1775       1878
# MaritalStatus         Single        Divorced      Single     Single
# NKids                      2               0           0          0
# NTeens                     1               0           1          0
# Income               30523.0        153924.0     30081.0    18890.0
# MntWines                   5               0          36          6
# MntFruits                  0               0           0          4
# MntMeatProducts            3               0           2          1
# MntFishProducts            0               0           0          7
# MntSweetProducts           0               0           0          2
# MntGoldProds               5               1           4         15
# TotalMnt                   8               0          38         20
# Complain                   0               0           0          0
# Recency                    0  Not Applicable          27          5
# NDealsPurchases            1               0           1          1
# NWebPurchases              1               0           1          0
# PWebPurchases      33.333333             NaN        25.0        0.0
# NCatalogPurchases          0               0           0          1
# PCatalogPurchases        0.0             NaN         0.0  33.333333
# NStorePurchases            2               0           3          2
# TotalPurchases             3               0           4          3
# NWebVisitsMonth            7               0           7          6
# Response1                  0               0           0          0
# Response2                  0               0           0          0
# Response3                  0               0           0          1
# Response4                  0               0           0          0
# Response5                  0               0           0          0
# Response                   0               0           0          1
#
# ID                      9499   ...       9937     2461       9606   \
# Education          Graduation  ...  Graduation   Master        PhD
# Age                        64  ...          39       63         53
# CustomerDays             1700  ...        1460     1475       1588
# MaritalStatus         Married  ...      Single   Single    Married
# NKids                       1  ...           0        1          0
# NTeens                      2  ...           0        1          0
# Income                93404.0  ...     70337.0  51124.0    69969.0
# MntWines                 1279  ...         187       26        882
# MntFruits                  15  ...          81        1         29
# MntMeatProducts           287  ...         149       11        514
# MntFishProducts            20  ...          25        0         38
# MntSweetProducts            0  ...          43        1         29
# MntGoldProds               15  ...          91        4         44
# TotalMnt                 1601  ...         485       39       1492
# Complain                    0  ...           0        0          0
# Recency                    97  ...          75       79         64
# NDealsPurchases             3  ...           1        2          1
# NWebPurchases               3  ...           2        1          4
# PWebPurchases       21.428571  ...        12.5     25.0  33.333333
# NCatalogPurchases           4  ...           2        0          2
# PCatalogPurchases   28.571429  ...        12.5      0.0  16.666667
# NStorePurchases             7  ...          12        3          6
# TotalPurchases             14  ...          16        4         12
# NWebVisitsMonth             5  ...           1        3          3
# Response1                   0  ...           0        0          1
# Response2                   0  ...           0        0          0
# Response3                   0  ...           0        0          0
# Response4                   1  ...           0        0          0
# Response5                   1  ...           0        0          1
# Response                    0  ...           0        0          1
#
# ID                      7214        6424        3887       5181        5758   \
# Education          Graduation  Graduation  Graduation      Basic  Graduation
# Age                        61          41          48         36          36
# CustomerDays             1641        1432        1877       1748        1448
# MaritalStatus         Married      Single      Single     Single     Married
# NKids                       0           1           1          1           0
# NTeens                      0           0           0          0           0
# Income                62187.0     33178.0     27242.0    24367.0     65169.0
# MntWines                  792          12           3          2        1074
# MntFruits                   0           6          17          4           0
# MntMeatProducts           275           2          26          2          69
# MntFishProducts            45          11          20          0           0
# MntSweetProducts           45           2           1         11           0
# MntGoldProds              126          16          39          5          46
# TotalMnt                 1157          33          67         19        1143
# Complain                    0           0           0          0           0
# Recency                    49           9           2         58          23
# NDealsPurchases             1           1           2          1           1
# NWebPurchases               4           1           2          1          10
# PWebPurchases       23.529412        25.0        40.0  33.333333   37.037037
# NCatalogPurchases           8           0           0          0           4
# PCatalogPurchases   47.058824         0.0         0.0        0.0   14.814815
# NStorePurchases             5           3           3          2          13
# TotalPurchases             17           4           5          3          27
# NWebVisitsMonth             3           4           9          9           6
# Response1                   0           0           0          0           1
# Response2                   0           0           0          0           1
# Response3                   0           0           0          0           1
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           1
# Response                    0           0           1          0           1
#
# ID                      9729       10478
# Education          Graduation        PhD
# Age                        63         68
# CustomerDays             1674       1922
# MaritalStatus           Widow    Married
# NKids                       1          1
# NTeens                      1          1
# Income                58275.0    55517.0
# MntWines                  189        483
# MntFruits                  10          0
# MntMeatProducts           253        108
# MntFishProducts            56          0
# MntSweetProducts           43          6
# MntGoldProds               64         36
# TotalMnt                  551        597
# Complain                    0          0
# Recency                    48         53
# NDealsPurchases             6          5
# NWebPurchases               8         11
# PWebPurchases       47.058824  61.111111
# NCatalogPurchases           2          1
# PCatalogPurchases   11.764706   5.555556
# NStorePurchases             7          6
# TotalPurchases             17         18
# NWebVisitsMonth             7          9
# Response1                   0          0
# Response2                   0          0
# Response3                   0          0
# Response4                   0          0
# Response5                   0          0
# Response                    0          1
#
# [30 rows x 2065 columns]

# %% [markdown]
# This ``filter()`` method generates a dataframe that exposes the relative and absolute values purchases made using the website.

# %%
data.filter(regex='NWebPurchases|PWebPurchases',axis=1)
# Out:
#        NWebPurchases  PWebPurchases
# ID
# 5314               7      53.846154
# 2493               7      43.750000
# 4931               0       0.000000
# 1100               3      42.857143
# 7224               1      25.000000
# ...              ...            ...
# 3887               2      40.000000
# 5181               1      33.333333
# 5758              10      37.037037
# 9729               8      47.058824
# 10478             11      61.111111
#
# [2065 rows x 2 columns]

# %% [markdown]
# <br>

# %% [markdown]
# **2.1.3** Percentage of Store purchases

# %% [markdown]
# The percentage of Store purchases is the proportion of the amount of purchases made in a store, by the total number of purchases made using the three different channels.
#
# In the next cell it is executed the function that returns the index of the column NStorePurchases.

# %%
get_columns_index("NStorePurchases", 'yes')
# Out:
# Index of column named NStorePurchases is: 21

# %% [markdown]
# NStorePurchases is at index 21, therefore, the feature PStorePurchases will be store at index 22.

# %% [markdown]
# The following code creates a feature with the mentioned percentage of NStorePurchases in TotalPurchases, which is placed in index 22.

# %%
percentages('NStorePurchases', 'TotalPurchases', 22, 'StorePurchases')
data.T
# Out:
# ID                      5314        2493        4931       1100        7224   \
# Education          Graduation  Graduation  Graduation     Master  Graduation
# Age                        67          52          41         58          41
# CustomerDays             1750        1613        1708       1379        1464
# MaritalStatus          Single     Married      Single     Single     Married
# NKids                       0           0           0          1           0
# NTeens                      1           1           0          2           0
# Income                40689.0     61286.0    157146.0    41275.0     31353.0
# MntWines                  270         356           1         24          10
# MntFruits                   3           0           0          4           0
# MntMeatProducts            27         107        1725         22          10
# MntFishProducts            39          19           2          0           3
# MntSweetProducts            6           9           1          2           1
# MntGoldProds               99         117           1          9           7
# TotalMnt                  345         491        1729         52          24
# Complain                    0           0           0          0           0
# Recency                    69          34          13         33          24
# NDealsPurchases             7           2           0          4           2
# NWebPurchases               7           7           0          3           1
# PWebPurchases       53.846154       43.75         0.0  42.857143        25.0
# NCatalogPurchases           1           1          28          1           1
# PCatalogPurchases    7.692308        6.25       100.0  14.285714        25.0
# NStorePurchases             5           8           0          3           2
# PStorePurchases     38.461538        50.0         0.0  42.857143        50.0
# TotalPurchases             13          16          28          7           4
# NWebVisitsMonth             8           5           1          5           8
# Response1                   0           0           0          0           0
# Response2                   0           0           0          0           0
# Response3                   0           0           0          0           0
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           0
# Response                    0           0           0          0           0
#
# ID                     2795            5555        10277      624    \
# Education             Master      Graduation  Graduation     Master
# Age                       60              43          57         34
# CustomerDays            1645            1424        1775       1878
# MaritalStatus         Single        Divorced      Single     Single
# NKids                      2               0           0          0
# NTeens                     1               0           1          0
# Income               30523.0        153924.0     30081.0    18890.0
# MntWines                   5               0          36          6
# MntFruits                  0               0           0          4
# MntMeatProducts            3               0           2          1
# MntFishProducts            0               0           0          7
# MntSweetProducts           0               0           0          2
# MntGoldProds               5               1           4         15
# TotalMnt                   8               0          38         20
# Complain                   0               0           0          0
# Recency                    0  Not Applicable          27          5
# NDealsPurchases            1               0           1          1
# NWebPurchases              1               0           1          0
# PWebPurchases      33.333333             NaN        25.0        0.0
# NCatalogPurchases          0               0           0          1
# PCatalogPurchases        0.0             NaN         0.0  33.333333
# NStorePurchases            2               0           3          2
# PStorePurchases    66.666667             NaN        75.0  66.666667
# TotalPurchases             3               0           4          3
# NWebVisitsMonth            7               0           7          6
# Response1                  0               0           0          0
# Response2                  0               0           0          0
# Response3                  0               0           0          1
# Response4                  0               0           0          0
# Response5                  0               0           0          0
# Response                   0               0           0          1
#
# ID                      9499   ...       9937     2461       9606   \
# Education          Graduation  ...  Graduation   Master        PhD
# Age                        64  ...          39       63         53
# CustomerDays             1700  ...        1460     1475       1588
# MaritalStatus         Married  ...      Single   Single    Married
# NKids                       1  ...           0        1          0
# NTeens                      2  ...           0        1          0
# Income                93404.0  ...     70337.0  51124.0    69969.0
# MntWines                 1279  ...         187       26        882
# MntFruits                  15  ...          81        1         29
# MntMeatProducts           287  ...         149       11        514
# MntFishProducts            20  ...          25        0         38
# MntSweetProducts            0  ...          43        1         29
# MntGoldProds               15  ...          91        4         44
# TotalMnt                 1601  ...         485       39       1492
# Complain                    0  ...           0        0          0
# Recency                    97  ...          75       79         64
# NDealsPurchases             3  ...           1        2          1
# NWebPurchases               3  ...           2        1          4
# PWebPurchases       21.428571  ...        12.5     25.0  33.333333
# NCatalogPurchases           4  ...           2        0          2
# PCatalogPurchases   28.571429  ...        12.5      0.0  16.666667
# NStorePurchases             7  ...          12        3          6
# PStorePurchases          50.0  ...        75.0     75.0       50.0
# TotalPurchases             14  ...          16        4         12
# NWebVisitsMonth             5  ...           1        3          3
# Response1                   0  ...           0        0          1
# Response2                   0  ...           0        0          0
# Response3                   0  ...           0        0          0
# Response4                   1  ...           0        0          0
# Response5                   1  ...           0        0          1
# Response                    0  ...           0        0          1
#
# ID                      7214        6424        3887       5181        5758   \
# Education          Graduation  Graduation  Graduation      Basic  Graduation
# Age                        61          41          48         36          36
# CustomerDays             1641        1432        1877       1748        1448
# MaritalStatus         Married      Single      Single     Single     Married
# NKids                       0           1           1          1           0
# NTeens                      0           0           0          0           0
# Income                62187.0     33178.0     27242.0    24367.0     65169.0
# MntWines                  792          12           3          2        1074
# MntFruits                   0           6          17          4           0
# MntMeatProducts           275           2          26          2          69
# MntFishProducts            45          11          20          0           0
# MntSweetProducts           45           2           1         11           0
# MntGoldProds              126          16          39          5          46
# TotalMnt                 1157          33          67         19        1143
# Complain                    0           0           0          0           0
# Recency                    49           9           2         58          23
# NDealsPurchases             1           1           2          1           1
# NWebPurchases               4           1           2          1          10
# PWebPurchases       23.529412        25.0        40.0  33.333333   37.037037
# NCatalogPurchases           8           0           0          0           4
# PCatalogPurchases   47.058824         0.0         0.0        0.0   14.814815
# NStorePurchases             5           3           3          2          13
# PStorePurchases     29.411765        75.0        60.0  66.666667   48.148148
# TotalPurchases             17           4           5          3          27
# NWebVisitsMonth             3           4           9          9           6
# Response1                   0           0           0          0           1
# Response2                   0           0           0          0           1
# Response3                   0           0           0          0           1
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           1
# Response                    0           0           1          0           1
#
# ID                      9729       10478
# Education          Graduation        PhD
# Age                        63         68
# CustomerDays             1674       1922
# MaritalStatus           Widow    Married
# NKids                       1          1
# NTeens                      1          1
# Income                58275.0    55517.0
# MntWines                  189        483
# MntFruits                  10          0
# MntMeatProducts           253        108
# MntFishProducts            56          0
# MntSweetProducts           43          6
# MntGoldProds               64         36
# TotalMnt                  551        597
# Complain                    0          0
# Recency                    48         53
# NDealsPurchases             6          5
# NWebPurchases               8         11
# PWebPurchases       47.058824  61.111111
# NCatalogPurchases           2          1
# PCatalogPurchases   11.764706   5.555556
# NStorePurchases             7          6
# PStorePurchases     41.176471  33.333333
# TotalPurchases             17         18
# NWebVisitsMonth             7          9
# Response1                   0          0
# Response2                   0          0
# Response3                   0          0
# Response4                   0          0
# Response5                   0          0
# Response                    0          1
#
# [31 rows x 2065 columns]

# %% [markdown]
# This ``filter()`` method generates a dataframe that exposes the relative and absolute values of purchases made in a store.

# %%
data.filter(regex='NStorePurchases|PStorePurchases',axis=1)
# Out:
#        NStorePurchases  PStorePurchases
# ID
# 5314                 5        38.461538
# 2493                 8        50.000000
# 4931                 0         0.000000
# 1100                 3        42.857143
# 7224                 2        50.000000
# ...                ...              ...
# 3887                 3        60.000000
# 5181                 2        66.666667
# 5758                13        48.148148
# 9729                 7        41.176471
# 10478                6        33.333333
#
# [2065 rows x 2 columns]

# %% [markdown]
# <br>
#
# #### **2.2** Percentage of the amount of money spent
#
# A useful feature that can assist in understanding on which product the largest and smallest amount of money spent is, is the percentage of money spent. This will allow us to know the proportion of money spent on each product.
#
# A similar process necessary to accomplish the creation of all the features corresponding to the amount of money spent was already executed for the percentage of purchases, step by step. Hence, we can now do the automatize that process. To do that, it is executed in the code below a for loop that will create a percentage feature for every Mnt column relatively to the TotalMnt.

# %%
MntColumns = ["MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts",'MntGoldProds']
# Use each Mnt column
for column in MntColumns:
    # Get the index of the column to place its percentage next to it
    index = get_columns_index(column, 'no')
    # Create the percentage feature, and place it an index after the column it represents
    percentages(column, 'TotalMnt', index + 1, column)
data.filter(regex ='Mnt')
# Out:
#        MntWines  PMntWines  MntFruits  PMntFruits  MntMeatProducts  \
# ID
# 5314        270  78.260870          3    0.869565               27
# 2493        356  72.505092          0    0.000000              107
# 4931          1   0.057837          0    0.000000             1725
# 1100         24  46.153846          4    7.692308               22
# 7224         10  41.666667          0    0.000000               10
# ...         ...        ...        ...         ...              ...
# 3887          3   4.477612         17   25.373134               26
# 5181          2  10.526316          4   21.052632                2
# 5758       1074  93.963255          0    0.000000               69
# 9729        189  34.301270         10    1.814882              253
# 10478       483  80.904523          0    0.000000              108
#
#        PMntMeatProducts  MntFishProducts  PMntFishProducts  MntSweetProducts  \
# ID
# 5314           7.826087               39         11.304348                 6
# 2493          21.792261               19          3.869654                 9
# 4931          99.768652                2          0.115674                 1
# 1100          42.307692                0          0.000000                 2
# 7224          41.666667                3         12.500000                 1
# ...                 ...              ...               ...               ...
# 3887          38.805970               20         29.850746                 1
# 5181          10.526316                0          0.000000                11
# 5758           6.036745                0          0.000000                 0
# 9729          45.916515               56         10.163339                43
# 10478         18.090452                0          0.000000                 6
#
#        PMntSweetProducts  MntGoldProds  PMntGoldProds  TotalMnt
# ID
# 5314            1.739130            99      28.695652       345
# 2493            1.832994           117      23.828921       491
# 4931            0.057837             1       0.057837      1729
# 1100            3.846154             9      17.307692        52
# 7224            4.166667             7      29.166667        24
# ...                  ...           ...            ...       ...
# 3887            1.492537            39      58.208955        67
# 5181           57.894737             5      26.315789        19
# 5758            0.000000            46       4.024497      1143
# 9729            7.803993            64      11.615245       551
# 10478           1.005025            36       6.030151       597
#
# [2065 rows x 13 columns]

# %% [markdown]
# Upon viewing the table above, it is clear that the generation of the new variables was successful.
#
# <br><br>

# %% [markdown]
# ### **3.** Child-related features
#
# Two new features will be created to have a better overview of the costumer's family situation. This can help, for instance, knowing the influence of having kids, what type of products the costumer buys and if it affects the decision making when deciding to accept the offer of the campaign or not.

# %% [markdown]
# #### **3.1** Number of Children

# %% [markdown]
# The cell bellow creates the feature NChildren, which is the sum of the number of kids and teenagers a costumer has. To create this feature, it can be used a modified version (``create_column``) of the function ``total()``.

# %%
# Modified version of total(), the modification is in the last row of the function, with column = name
def create_column(columns, name, index):
    total = 0
    for column in columns:
        total += data[column]
    # The name of the new column is given as a parameter of the function by name
    data.insert(loc=index, column= name, value = total)

# Getting the index of the column NTeens
index = get_columns_index('NTeens', 'no')

# Creating NChildren
create_column(['NKids', 'NTeens'], 'NChildren', index+1)

# Displaying the transposed version of the data
data.T
# Out:
# ID                      5314        2493        4931       1100        7224   \
# Education          Graduation  Graduation  Graduation     Master  Graduation
# Age                        67          52          41         58          41
# CustomerDays             1750        1613        1708       1379        1464
# MaritalStatus          Single     Married      Single     Single     Married
# NKids                       0           0           0          1           0
# NTeens                      1           1           0          2           0
# NChildren                   1           1           0          3           0
# Income                40689.0     61286.0    157146.0    41275.0     31353.0
# MntWines                  270         356           1         24          10
# PMntWines            78.26087   72.505092    0.057837  46.153846   41.666667
# MntFruits                   3           0           0          4           0
# PMntFruits           0.869565         0.0         0.0   7.692308         0.0
# MntMeatProducts            27         107        1725         22          10
# PMntMeatProducts     7.826087   21.792261   99.768652  42.307692   41.666667
# MntFishProducts            39          19           2          0           3
# PMntFishProducts    11.304348    3.869654    0.115674        0.0        12.5
# MntSweetProducts            6           9           1          2           1
# PMntSweetProducts     1.73913    1.832994    0.057837   3.846154    4.166667
# MntGoldProds               99         117           1          9           7
# PMntGoldProds       28.695652   23.828921    0.057837  17.307692   29.166667
# TotalMnt                  345         491        1729         52          24
# Complain                    0           0           0          0           0
# Recency                    69          34          13         33          24
# NDealsPurchases             7           2           0          4           2
# NWebPurchases               7           7           0          3           1
# PWebPurchases       53.846154       43.75         0.0  42.857143        25.0
# NCatalogPurchases           1           1          28          1           1
# PCatalogPurchases    7.692308        6.25       100.0  14.285714        25.0
# NStorePurchases             5           8           0          3           2
# PStorePurchases     38.461538        50.0         0.0  42.857143        50.0
# TotalPurchases             13          16          28          7           4
# NWebVisitsMonth             8           5           1          5           8
# Response1                   0           0           0          0           0
# Response2                   0           0           0          0           0
# Response3                   0           0           0          0           0
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           0
# Response                    0           0           0          0           0
#
# ID                     2795            5555        10277      624    \
# Education             Master      Graduation  Graduation     Master
# Age                       60              43          57         34
# CustomerDays            1645            1424        1775       1878
# MaritalStatus         Single        Divorced      Single     Single
# NKids                      2               0           0          0
# NTeens                     1               0           1          0
# NChildren                  3               0           1          0
# Income               30523.0        153924.0     30081.0    18890.0
# MntWines                   5               0          36          6
# PMntWines               62.5             NaN   94.736842       30.0
# MntFruits                  0               0           0          4
# PMntFruits               0.0             NaN         0.0       20.0
# MntMeatProducts            3               0           2          1
# PMntMeatProducts        37.5             NaN    5.263158        5.0
# MntFishProducts            0               0           0          7
# PMntFishProducts         0.0             NaN         0.0       35.0
# MntSweetProducts           0               0           0          2
# PMntSweetProducts        0.0             NaN         0.0       10.0
# MntGoldProds               5               1           4         15
# PMntGoldProds           62.5             inf   10.526316       75.0
# TotalMnt                   8               0          38         20
# Complain                   0               0           0          0
# Recency                    0  Not Applicable          27          5
# NDealsPurchases            1               0           1          1
# NWebPurchases              1               0           1          0
# PWebPurchases      33.333333             NaN        25.0        0.0
# NCatalogPurchases          0               0           0          1
# PCatalogPurchases        0.0             NaN         0.0  33.333333
# NStorePurchases            2               0           3          2
# PStorePurchases    66.666667             NaN        75.0  66.666667
# TotalPurchases             3               0           4          3
# NWebVisitsMonth            7               0           7          6
# Response1                  0               0           0          0
# Response2                  0               0           0          0
# Response3                  0               0           0          1
# Response4                  0               0           0          0
# Response5                  0               0           0          0
# Response                   0               0           0          1
#
# ID                      9499   ...       9937       2461       9606   \
# Education          Graduation  ...  Graduation     Master        PhD
# Age                        64  ...          39         63         53
# CustomerDays             1700  ...        1460       1475       1588
# MaritalStatus         Married  ...      Single     Single    Married
# NKids                       1  ...           0          1          0
# NTeens                      2  ...           0          1          0
# NChildren                   3  ...           0          2          0
# Income                93404.0  ...     70337.0    51124.0    69969.0
# MntWines                 1279  ...         187         26        882
# PMntWines            79.88757  ...   38.556701  66.666667  59.115282
# MntFruits                  15  ...          81          1         29
# PMntFruits           0.936914  ...   16.701031   2.564103     1.9437
# MntMeatProducts           287  ...         149         11        514
# PMntMeatProducts    17.926296  ...   30.721649  28.205128  34.450402
# MntFishProducts            20  ...          25          0         38
# PMntFishProducts     1.249219  ...    5.154639        0.0   2.546917
# MntSweetProducts            0  ...          43          1         29
# PMntSweetProducts         0.0  ...    8.865979   2.564103     1.9437
# MntGoldProds               15  ...          91          4         44
# PMntGoldProds        0.936914  ...   18.762887   10.25641   2.949062
# TotalMnt                 1601  ...         485         39       1492
# Complain                    0  ...           0          0          0
# Recency                    97  ...          75         79         64
# NDealsPurchases             3  ...           1          2          1
# NWebPurchases               3  ...           2          1          4
# PWebPurchases       21.428571  ...        12.5       25.0  33.333333
# NCatalogPurchases           4  ...           2          0          2
# PCatalogPurchases   28.571429  ...        12.5        0.0  16.666667
# NStorePurchases             7  ...          12          3          6
# PStorePurchases          50.0  ...        75.0       75.0       50.0
# TotalPurchases             14  ...          16          4         12
# NWebVisitsMonth             5  ...           1          3          3
# Response1                   0  ...           0          0          1
# Response2                   0  ...           0          0          0
# Response3                   0  ...           0          0          0
# Response4                   1  ...           0          0          0
# Response5                   1  ...           0          0          1
# Response                    0  ...           0          0          1
#
# ID                      7214        6424        3887       5181        5758   \
# Education          Graduation  Graduation  Graduation      Basic  Graduation
# Age                        61          41          48         36          36
# CustomerDays             1641        1432        1877       1748        1448
# MaritalStatus         Married      Single      Single     Single     Married
# NKids                       0           1           1          1           0
# NTeens                      0           0           0          0           0
# NChildren                   0           1           1          1           0
# Income                62187.0     33178.0     27242.0    24367.0     65169.0
# MntWines                  792          12           3          2        1074
# PMntWines           68.452895   36.363636    4.477612  10.526316   93.963255
# MntFruits                   0           6          17          4           0
# PMntFruits                0.0   18.181818   25.373134  21.052632         0.0
# MntMeatProducts           275           2          26          2          69
# PMntMeatProducts    23.768366    6.060606    38.80597  10.526316    6.036745
# MntFishProducts            45          11          20          0           0
# PMntFishProducts     3.889369   33.333333   29.850746        0.0         0.0
# MntSweetProducts           45           2           1         11           0
# PMntSweetProducts    3.889369    6.060606    1.492537  57.894737         0.0
# MntGoldProds              126          16          39          5          46
# PMntGoldProds       10.890233   48.484848   58.208955  26.315789    4.024497
# TotalMnt                 1157          33          67         19        1143
# Complain                    0           0           0          0           0
# Recency                    49           9           2         58          23
# NDealsPurchases             1           1           2          1           1
# NWebPurchases               4           1           2          1          10
# PWebPurchases       23.529412        25.0        40.0  33.333333   37.037037
# NCatalogPurchases           8           0           0          0           4
# PCatalogPurchases   47.058824         0.0         0.0        0.0   14.814815
# NStorePurchases             5           3           3          2          13
# PStorePurchases     29.411765        75.0        60.0  66.666667   48.148148
# TotalPurchases             17           4           5          3          27
# NWebVisitsMonth             3           4           9          9           6
# Response1                   0           0           0          0           1
# Response2                   0           0           0          0           1
# Response3                   0           0           0          0           1
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           1
# Response                    0           0           1          0           1
#
# ID                      9729       10478
# Education          Graduation        PhD
# Age                        63         68
# CustomerDays             1674       1922
# MaritalStatus           Widow    Married
# NKids                       1          1
# NTeens                      1          1
# NChildren                   2          2
# Income                58275.0    55517.0
# MntWines                  189        483
# PMntWines            34.30127  80.904523
# MntFruits                  10          0
# PMntFruits           1.814882        0.0
# MntMeatProducts           253        108
# PMntMeatProducts    45.916515  18.090452
# MntFishProducts            56          0
# PMntFishProducts    10.163339        0.0
# MntSweetProducts           43          6
# PMntSweetProducts    7.803993   1.005025
# MntGoldProds               64         36
# PMntGoldProds       11.615245   6.030151
# TotalMnt                  551        597
# Complain                    0          0
# Recency                    48         53
# NDealsPurchases             6          5
# NWebPurchases               8         11
# PWebPurchases       47.058824  61.111111
# NCatalogPurchases           2          1
# PCatalogPurchases   11.764706   5.555556
# NStorePurchases             7          6
# PStorePurchases     41.176471  33.333333
# TotalPurchases             17         18
# NWebVisitsMonth             7          9
# Response1                   0          0
# Response2                   0          0
# Response3                   0          0
# Response4                   0          0
# Response5                   0          0
# Response                    0          1
#
# [38 rows x 2065 columns]

# %% [markdown]
# <br>
#
# #### **3.2** Has Child

# %% [markdown]
# The second child-related feature is HasChild, which represents the customers that have at least one child. That is, if an individual has a kid or a teen, its corresponding HasChild is equal to 1. If one indivual does not have children, HasChild is equal to 0.
#
# In the code below, it is created the above-mentioned feature.

# %%
# Getting the values for HasChild
HasChild = np.where(data.NChildren > 0, 1, 0)
# Getting the index of NChildren, the last column about children in the dataset
index = get_columns_index('NChildren', 'no')
# Adding the column to the dataset
data.insert(loc=index+1, column= 'HasChild', value = HasChild)
# Displaying the data transposed
data.T
# Out:
# ID                      5314        2493        4931       1100        7224   \
# Education          Graduation  Graduation  Graduation     Master  Graduation
# Age                        67          52          41         58          41
# CustomerDays             1750        1613        1708       1379        1464
# MaritalStatus          Single     Married      Single     Single     Married
# NKids                       0           0           0          1           0
# NTeens                      1           1           0          2           0
# NChildren                   1           1           0          3           0
# HasChild                    1           1           0          1           0
# Income                40689.0     61286.0    157146.0    41275.0     31353.0
# MntWines                  270         356           1         24          10
# PMntWines            78.26087   72.505092    0.057837  46.153846   41.666667
# MntFruits                   3           0           0          4           0
# PMntFruits           0.869565         0.0         0.0   7.692308         0.0
# MntMeatProducts            27         107        1725         22          10
# PMntMeatProducts     7.826087   21.792261   99.768652  42.307692   41.666667
# MntFishProducts            39          19           2          0           3
# PMntFishProducts    11.304348    3.869654    0.115674        0.0        12.5
# MntSweetProducts            6           9           1          2           1
# PMntSweetProducts     1.73913    1.832994    0.057837   3.846154    4.166667
# MntGoldProds               99         117           1          9           7
# PMntGoldProds       28.695652   23.828921    0.057837  17.307692   29.166667
# TotalMnt                  345         491        1729         52          24
# Complain                    0           0           0          0           0
# Recency                    69          34          13         33          24
# NDealsPurchases             7           2           0          4           2
# NWebPurchases               7           7           0          3           1
# PWebPurchases       53.846154       43.75         0.0  42.857143        25.0
# NCatalogPurchases           1           1          28          1           1
# PCatalogPurchases    7.692308        6.25       100.0  14.285714        25.0
# NStorePurchases             5           8           0          3           2
# PStorePurchases     38.461538        50.0         0.0  42.857143        50.0
# TotalPurchases             13          16          28          7           4
# NWebVisitsMonth             8           5           1          5           8
# Response1                   0           0           0          0           0
# Response2                   0           0           0          0           0
# Response3                   0           0           0          0           0
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           0
# Response                    0           0           0          0           0
#
# ID                     2795            5555        10277      624    \
# Education             Master      Graduation  Graduation     Master
# Age                       60              43          57         34
# CustomerDays            1645            1424        1775       1878
# MaritalStatus         Single        Divorced      Single     Single
# NKids                      2               0           0          0
# NTeens                     1               0           1          0
# NChildren                  3               0           1          0
# HasChild                   1               0           1          0
# Income               30523.0        153924.0     30081.0    18890.0
# MntWines                   5               0          36          6
# PMntWines               62.5             NaN   94.736842       30.0
# MntFruits                  0               0           0          4
# PMntFruits               0.0             NaN         0.0       20.0
# MntMeatProducts            3               0           2          1
# PMntMeatProducts        37.5             NaN    5.263158        5.0
# MntFishProducts            0               0           0          7
# PMntFishProducts         0.0             NaN         0.0       35.0
# MntSweetProducts           0               0           0          2
# PMntSweetProducts        0.0             NaN         0.0       10.0
# MntGoldProds               5               1           4         15
# PMntGoldProds           62.5             inf   10.526316       75.0
# TotalMnt                   8               0          38         20
# Complain                   0               0           0          0
# Recency                    0  Not Applicable          27          5
# NDealsPurchases            1               0           1          1
# NWebPurchases              1               0           1          0
# PWebPurchases      33.333333             NaN        25.0        0.0
# NCatalogPurchases          0               0           0          1
# PCatalogPurchases        0.0             NaN         0.0  33.333333
# NStorePurchases            2               0           3          2
# PStorePurchases    66.666667             NaN        75.0  66.666667
# TotalPurchases             3               0           4          3
# NWebVisitsMonth            7               0           7          6
# Response1                  0               0           0          0
# Response2                  0               0           0          0
# Response3                  0               0           0          1
# Response4                  0               0           0          0
# Response5                  0               0           0          0
# Response                   0               0           0          1
#
# ID                      9499   ...       9937       2461       9606   \
# Education          Graduation  ...  Graduation     Master        PhD
# Age                        64  ...          39         63         53
# CustomerDays             1700  ...        1460       1475       1588
# MaritalStatus         Married  ...      Single     Single    Married
# NKids                       1  ...           0          1          0
# NTeens                      2  ...           0          1          0
# NChildren                   3  ...           0          2          0
# HasChild                    1  ...           0          1          0
# Income                93404.0  ...     70337.0    51124.0    69969.0
# MntWines                 1279  ...         187         26        882
# PMntWines            79.88757  ...   38.556701  66.666667  59.115282
# MntFruits                  15  ...          81          1         29
# PMntFruits           0.936914  ...   16.701031   2.564103     1.9437
# MntMeatProducts           287  ...         149         11        514
# PMntMeatProducts    17.926296  ...   30.721649  28.205128  34.450402
# MntFishProducts            20  ...          25          0         38
# PMntFishProducts     1.249219  ...    5.154639        0.0   2.546917
# MntSweetProducts            0  ...          43          1         29
# PMntSweetProducts         0.0  ...    8.865979   2.564103     1.9437
# MntGoldProds               15  ...          91          4         44
# PMntGoldProds        0.936914  ...   18.762887   10.25641   2.949062
# TotalMnt                 1601  ...         485         39       1492
# Complain                    0  ...           0          0          0
# Recency                    97  ...          75         79         64
# NDealsPurchases             3  ...           1          2          1
# NWebPurchases               3  ...           2          1          4
# PWebPurchases       21.428571  ...        12.5       25.0  33.333333
# NCatalogPurchases           4  ...           2          0          2
# PCatalogPurchases   28.571429  ...        12.5        0.0  16.666667
# NStorePurchases             7  ...          12          3          6
# PStorePurchases          50.0  ...        75.0       75.0       50.0
# TotalPurchases             14  ...          16          4         12
# NWebVisitsMonth             5  ...           1          3          3
# Response1                   0  ...           0          0          1
# Response2                   0  ...           0          0          0
# Response3                   0  ...           0          0          0
# Response4                   1  ...           0          0          0
# Response5                   1  ...           0          0          1
# Response                    0  ...           0          0          1
#
# ID                      7214        6424        3887       5181        5758   \
# Education          Graduation  Graduation  Graduation      Basic  Graduation
# Age                        61          41          48         36          36
# CustomerDays             1641        1432        1877       1748        1448
# MaritalStatus         Married      Single      Single     Single     Married
# NKids                       0           1           1          1           0
# NTeens                      0           0           0          0           0
# NChildren                   0           1           1          1           0
# HasChild                    0           1           1          1           0
# Income                62187.0     33178.0     27242.0    24367.0     65169.0
# MntWines                  792          12           3          2        1074
# PMntWines           68.452895   36.363636    4.477612  10.526316   93.963255
# MntFruits                   0           6          17          4           0
# PMntFruits                0.0   18.181818   25.373134  21.052632         0.0
# MntMeatProducts           275           2          26          2          69
# PMntMeatProducts    23.768366    6.060606    38.80597  10.526316    6.036745
# MntFishProducts            45          11          20          0           0
# PMntFishProducts     3.889369   33.333333   29.850746        0.0         0.0
# MntSweetProducts           45           2           1         11           0
# PMntSweetProducts    3.889369    6.060606    1.492537  57.894737         0.0
# MntGoldProds              126          16          39          5          46
# PMntGoldProds       10.890233   48.484848   58.208955  26.315789    4.024497
# TotalMnt                 1157          33          67         19        1143
# Complain                    0           0           0          0           0
# Recency                    49           9           2         58          23
# NDealsPurchases             1           1           2          1           1
# NWebPurchases               4           1           2          1          10
# PWebPurchases       23.529412        25.0        40.0  33.333333   37.037037
# NCatalogPurchases           8           0           0          0           4
# PCatalogPurchases   47.058824         0.0         0.0        0.0   14.814815
# NStorePurchases             5           3           3          2          13
# PStorePurchases     29.411765        75.0        60.0  66.666667   48.148148
# TotalPurchases             17           4           5          3          27
# NWebVisitsMonth             3           4           9          9           6
# Response1                   0           0           0          0           1
# Response2                   0           0           0          0           1
# Response3                   0           0           0          0           1
# Response4                   0           0           0          0           0
# Response5                   0           0           0          0           1
# Response                    0           0           1          0           1
#
# ID                      9729       10478
# Education          Graduation        PhD
# Age                        63         68
# CustomerDays             1674       1922
# MaritalStatus           Widow    Married
# NKids                       1          1
# NTeens                      1          1
# NChildren                   2          2
# HasChild                    1          1
# Income                58275.0    55517.0
# MntWines                  189        483
# PMntWines            34.30127  80.904523
# MntFruits                  10          0
# PMntFruits           1.814882        0.0
# MntMeatProducts           253        108
# PMntMeatProducts    45.916515  18.090452
# MntFishProducts            56          0
# PMntFishProducts    10.163339        0.0
# MntSweetProducts           43          6
# PMntSweetProducts    7.803993   1.005025
# MntGoldProds               64         36
# PMntGoldProds       11.615245   6.030151
# TotalMnt                  551        597
# Complain                    0          0
# Recency                    48         53
# NDealsPurchases             6          5
# NWebPurchases               8         11
# PWebPurchases       47.058824  61.111111
# NCatalogPurchases           2          1
# PCatalogPurchases   11.764706   5.555556
# NStorePurchases             7          6
# PStorePurchases     41.176471  33.333333
# TotalPurchases             17         18
# NWebVisitsMonth             7          9
# Response1                   0          0
# Response2                   0          0
# Response3                   0          0
# Response4                   0          0
# Response5                   0          0
# Response                    0          1
#
# [39 rows x 2065 columns]

# %% [markdown]
# <br>

# %% [markdown]
# ### **4.** NaN/Infinite Values
#
# Some of the extracted features, namely the precentages, contain NaN/Infinite values, given the fact that some denominators are 0. The cell bellow returns the number of NaN values each feature has, using the ``.isin()`` method.

# %%
# List containing the columns with the NaN values
columns = ["PCatalogPurchases", "PWebPurchases", "PStorePurchases", "PMntWines","PMntFruits","PMntMeatProducts","PMntFishProducts","PMntSweetProducts",'PMntGoldProds']
# isin() checks whether there is NaN/Infinite values and infinite values (either positive and negative) in columns
print(data[columns].isin([np.nan, np.inf, -np.inf]).sum())
# Out:
# PCatalogPurchases    6
# PWebPurchases        6
# PStorePurchases      6
# PMntWines            6
# PMntFruits           6
# PMntMeatProducts     6
# PMntFishProducts     6
# PMntSweetProducts    6
# PMntGoldProds        6
# dtype: int64

# %% [markdown]
# The number of missing values are equal to 6 in each column, since it is a very small number (regarding the size of the dataset), the NaN/Infinite values can be replace with the mean value of each variable. The following cell replaces the NaN/Infinite values and checks if there is any after replacement, using the ``.isin()`` method.

# %%
for missingvalues in columns:
    data[missingvalues].replace(to_replace=[np.nan, np.inf, -np.inf], value=data[missingvalues].mean(), inplace=True)
    print("Is there any NaN or Infinite value in {} after replacement? R:".format(missingvalues),
      data[missingvalues].isin([np.nan, np.inf, -np.inf]).any())
# Out:
# Is there any NaN or Infinite value in PCatalogPurchases after replacement? R: False
# Is there any NaN or Infinite value in PWebPurchases after replacement? R: False
# Is there any NaN or Infinite value in PStorePurchases after replacement? R: False
# Is there any NaN or Infinite value in PMntWines after replacement? R: False
# Is there any NaN or Infinite value in PMntFruits after replacement? R: False
# Is there any NaN or Infinite value in PMntMeatProducts after replacement? R: False
# Is there any NaN or Infinite value in PMntFishProducts after replacement? R: False
# Is there any NaN or Infinite value in PMntSweetProducts after replacement? R: False
# Is there any NaN or Infinite value in PMntGoldProds after replacement? R: True

# %% [markdown]
# <br>

# %% [markdown]
# ### **5.** Redundancy analysis

# %% [markdown]
# A statistical technique for evaluating the redundancy existent in a datset is correlation analysis. This will identify which variables are highly correlation between each other and therefore explain each others behaviour. The columns that have that form of correlation can be revealed as unecessary. This process be done using ``.corr()`` method, which is able to exclude null values.
#
# First, the columns for which the correlation will be calculated are chosen (numerical columns). In the cell below, a list with all these columns is created.

# %%
# Numerical columns' names of the 'data' dataset stored in the 'numerical_columns' array
numerical_columns = data.select_dtypes(include = "number").columns
# Converting the array 'numerical_columns' into a list
numerical_columns = list(numerical_columns)
# Removing the element 'Response' from the list
numerical_columns.remove('Response')
# Displaying the list
print(numerical_columns)
# Out:
# ['Age', 'CustomerDays', 'NKids', 'NTeens', 'NChildren', 'HasChild', 'Income', 'MntWines', 'PMntWines', 'MntFruits', 'PMntFruits', 'MntMeatProducts', 'PMntMeatProducts', 'MntFishProducts', 'PMntFishProducts', 'MntSweetProducts', 'PMntSweetProducts', 'MntGoldProds', 'PMntGoldProds', 'TotalMnt', 'Complain', 'NDealsPurchases', 'NWebPurchases', 'PWebPurchases', 'NCatalogPurchases', 'PCatalogPurchases', 'NStorePurchases', 'PStorePurchases', 'TotalPurchases', 'NWebVisitsMonth', 'Response1', 'Response2', 'Response3', 'Response4', 'Response5']

# %% [markdown]
# Afterwards, it is used the spearman's coefficient to calculate the correlation between the features stored in the list above. In this case the spearman's coefficient was choosen instead of the pearson's due to its properties. That is, whereas the pearson's can only calculate linear correlations, the spearman's coefficient can not only calculate those types of correlations, but also the non-linear ones. Therefore, it can work with non-numeric features.
#
# In the code below, the correlation matrix is being computed and displayed.

# %%
# Computing the correlation matrix, using spearman's coefficient between all the numerical features
plcc = data.loc[:, numerical_columns].corr(method="spearman")

# Displays the correlation matrix
plcc.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_92434_row0_col0, #T_92434_row1_col1, #T_92434_row2_col2, #T_92434_row3_col3, #T_92434_row4_col4, #T_92434_row5_col5, #T_92434_row6_col6, #T_92434_row7_col7, #T_92434_row8_col8, #T_92434_row9_col9, #T_92434_row10_col10, #T_92434_row11_col11, #T_92434_row12_col12, #T_92434_row13_col13, #T_92434_row14_col14, #T_92434_row15_col15, #T_92434_row16_col16, #T_92434_row17_col17, #T_92434_row18_col18, #T_92434_row19_col19, #T_92434_row20_col20, #T_92434_row21_col21, #T_92434_row22_col22, #T_92434_row23_col23, #T_92434_row24_col24, #T_92434_row25_col25, #T_92434_row26_col26, #T_92434_row27_col27, #T_92434_row28_col28, #T_92434_row29_col29, #T_92434_row30_col30, #T_92434_row31_col31, #T_92434_row32_col32, #T_92434_row33_col33, #T_92434_row34_col34 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_92434_row0_col1, #T_92434_row6_col23, #T_92434_row27_col34, #T_92434_row34_col1 {
#   background-color: #ffec9f;
#   color: #000000;
# }
# #T_92434_row0_col2, #T_92434_row9_col18, #T_92434_row18_col8, #T_92434_row20_col21, #T_92434_row23_col24 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_92434_row0_col3, #T_92434_row29_col18 {
#   background-color: #fd7435;
#   color: #f1f1f1;
# }
# #T_92434_row0_col4, #T_92434_row1_col18, #T_92434_row8_col21, #T_92434_row10_col2, #T_92434_row10_col24, #T_92434_row12_col18, #T_92434_row13_col30, #T_92434_row16_col11, #T_92434_row17_col12, #T_92434_row26_col30 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_92434_row0_col5, #T_92434_row16_col29, #T_92434_row32_col23 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_92434_row0_col6, #T_92434_row8_col6, #T_92434_row16_col13, #T_92434_row23_col2, #T_92434_row29_col21, #T_92434_row33_col22 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_92434_row0_col7, #T_92434_row7_col34, #T_92434_row16_col12 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_92434_row0_col8, #T_92434_row3_col21, #T_92434_row30_col6 {
#   background-color: #fc6631;
#   color: #f1f1f1;
# }
# #T_92434_row0_col9, #T_92434_row3_col25, #T_92434_row6_col16, #T_92434_row8_col27, #T_92434_row21_col11, #T_92434_row22_col14, #T_92434_row22_col33, #T_92434_row23_col16, #T_92434_row24_col33 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_92434_row0_col10, #T_92434_row11_col33, #T_92434_row17_col21, #T_92434_row25_col32, #T_92434_row25_col33, #T_92434_row33_col14, #T_92434_row33_col16 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_92434_row0_col11, #T_92434_row9_col34, #T_92434_row12_col9, #T_92434_row12_col13, #T_92434_row16_col17, #T_92434_row16_col27, #T_92434_row25_col8, #T_92434_row25_col12, #T_92434_row27_col10, #T_92434_row32_col8, #T_92434_row32_col22 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_92434_row0_col12, #T_92434_row4_col12, #T_92434_row11_col1, #T_92434_row18_col32, #T_92434_row28_col1 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_92434_row0_col13, #T_92434_row0_col27, #T_92434_row10_col28, #T_92434_row17_col1, #T_92434_row19_col0, #T_92434_row20_col11, #T_92434_row22_col10, #T_92434_row23_col17, #T_92434_row26_col12, #T_92434_row29_col10 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_92434_row0_col14, #T_92434_row12_col26, #T_92434_row14_col6, #T_92434_row26_col27, #T_92434_row28_col3, #T_92434_row32_col26 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_92434_row0_col15, #T_92434_row5_col14, #T_92434_row12_col29, #T_92434_row20_col9, #T_92434_row20_col13, #T_92434_row22_col12, #T_92434_row33_col3, #T_92434_row34_col27 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_92434_row0_col16, #T_92434_row4_col10, #T_92434_row4_col14, #T_92434_row12_col34, #T_92434_row17_col32, #T_92434_row26_col21, #T_92434_row27_col3 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_92434_row0_col17, #T_92434_row2_col10, #T_92434_row3_col28, #T_92434_row12_col24, #T_92434_row16_col24, #T_92434_row19_col12, #T_92434_row20_col2, #T_92434_row20_col14, #T_92434_row20_col29, #T_92434_row24_col14, #T_92434_row29_col1, #T_92434_row32_col19, #T_92434_row34_col16 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_92434_row0_col18, #T_92434_row0_col33, #T_92434_row0_col34, #T_92434_row12_col30, #T_92434_row19_col3, #T_92434_row21_col15, #T_92434_row24_col32, #T_92434_row26_col1, #T_92434_row30_col18 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_92434_row0_col19, #T_92434_row8_col26, #T_92434_row8_col28, #T_92434_row14_col9, #T_92434_row33_col26 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_92434_row0_col20, #T_92434_row2_col24, #T_92434_row4_col30, #T_92434_row5_col15, #T_92434_row9_col20, #T_92434_row15_col4, #T_92434_row23_col31, #T_92434_row27_col28, #T_92434_row34_col20 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_92434_row0_col21, #T_92434_row7_col16, #T_92434_row9_col1, #T_92434_row13_col1, #T_92434_row18_col21, #T_92434_row21_col6, #T_92434_row23_col11, #T_92434_row30_col29, #T_92434_row31_col5, #T_92434_row33_col0 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_92434_row0_col22, #T_92434_row3_col0, #T_92434_row5_col27, #T_92434_row10_col13, #T_92434_row10_col18, #T_92434_row14_col18, #T_92434_row17_col18, #T_92434_row23_col21 {
#   background-color: #fd8a3b;
#   color: #f1f1f1;
# }
# #T_92434_row0_col23, #T_92434_row7_col1, #T_92434_row20_col3, #T_92434_row33_col2 {
#   background-color: #fed16e;
#   color: #000000;
# }
# #T_92434_row0_col24, #T_92434_row1_col17, #T_92434_row8_col4, #T_92434_row9_col12, #T_92434_row11_col34 {
#   background-color: #fd8e3c;
#   color: #f1f1f1;
# }
# #T_92434_row0_col25, #T_92434_row18_col27, #T_92434_row23_col8 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_92434_row0_col26, #T_92434_row1_col7, #T_92434_row1_col24, #T_92434_row4_col18, #T_92434_row17_col10, #T_92434_row17_col16, #T_92434_row19_col30, #T_92434_row34_col9 {
#   background-color: #fd9640;
#   color: #000000;
# }
# #T_92434_row0_col28, #T_92434_row4_col23, #T_92434_row5_col18, #T_92434_row34_col15 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_92434_row0_col29, #T_92434_row5_col16, #T_92434_row8_col2, #T_92434_row8_col34, #T_92434_row11_col0, #T_92434_row17_col23, #T_92434_row19_col1, #T_92434_row32_col13, #T_92434_row32_col27 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_92434_row0_col30, #T_92434_row14_col5, #T_92434_row15_col18, #T_92434_row31_col0, #T_92434_row34_col29 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_92434_row0_col31, #T_92434_row4_col19, #T_92434_row19_col29, #T_92434_row28_col27, #T_92434_row34_col5 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_92434_row0_col32, #T_92434_row1_col31, #T_92434_row2_col1, #T_92434_row6_col4, #T_92434_row9_col31, #T_92434_row11_col27 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_92434_row1_col0, #T_92434_row1_col33, #T_92434_row5_col0, #T_92434_row10_col4, #T_92434_row11_col23, #T_92434_row20_col30, #T_92434_row22_col4 {
#   background-color: #fee288;
#   color: #000000;
# }
# #T_92434_row1_col2, #T_92434_row20_col7, #T_92434_row20_col26, #T_92434_row22_col16, #T_92434_row26_col0, #T_92434_row26_col33, #T_92434_row31_col10 {
#   background-color: #febb56;
#   color: #000000;
# }
# #T_92434_row1_col3, #T_92434_row33_col23, #T_92434_row34_col31 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_92434_row1_col4, #T_92434_row1_col27, #T_92434_row5_col10, #T_92434_row6_col3, #T_92434_row20_col23, #T_92434_row23_col7, #T_92434_row31_col15, #T_92434_row32_col4, #T_92434_row32_col5, #T_92434_row33_col15 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_92434_row1_col5, #T_92434_row10_col6, #T_92434_row14_col26, #T_92434_row16_col6, #T_92434_row22_col1, #T_92434_row29_col12, #T_92434_row31_col13, #T_92434_row33_col13 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_92434_row1_col6, #T_92434_row19_col16, #T_92434_row21_col24, #T_92434_row23_col3, #T_92434_row26_col14, #T_92434_row28_col10, #T_92434_row30_col10, #T_92434_row32_col6 {
#   background-color: #feb44e;
#   color: #000000;
# }
# #T_92434_row1_col8, #T_92434_row1_col15, #T_92434_row7_col0, #T_92434_row8_col33, #T_92434_row15_co

# %% [markdown]
# <br>
# In order to get a better overview of each correlation, the following cell is used. The function ``np.triu()`` takes the upper triangle of the matrix, removing duplicates and low-correlated pairs. It is then displayed the values of the highest correlation pairs.

# %%
# Reshapes the dataframe by converting the data into a stacked form
plcc_u = plcc.stack()

# Get the upper triangle of the matrix
tri_u = np.triu(np.ones(plcc.shape)).astype('bool').reshape(plcc.size)  

# Select unique pairs
plcc_u = plcc_u[tri_u]  

# Removes the low-correlated pairs and the auto-correlations, given a specified threshold
l_threshold = 0.7

u_threshold = 1
plcc_top = plcc_u[(plcc_u.abs() > l_threshold) & (plcc_u.abs() < u_threshold) & (plcc_u!=1.0)]

# Prints the output
print("Top most correlated feature pairs:\n", plcc_top.abs().sort_values(ascending=False))
# Out:
# Top most correlated feature pairs:
#  MntMeatProducts    TotalMnt             0.942492
# MntWines           TotalMnt             0.934322
# NCatalogPurchases  PCatalogPurchases    0.912137
# TotalMnt           TotalPurchases       0.910064
# NStorePurchases    TotalPurchases       0.890645
# TotalMnt           NCatalogPurchases    0.884669
# NCatalogPurchases  TotalPurchases       0.875974
# MntWines           TotalPurchases       0.869805
# MntMeatProducts    TotalPurchases       0.864135
# NChildren          HasChild             0.856953
# MntMeatProducts    NCatalogPurchases    0.850073
# NWebPurchases      TotalPurchases       0.830922
# MntWines           NCatalogPurchases    0.822583
#                    MntMeatProducts      0.820524
# TotalMnt           NStorePurchases      0.812685
# Income             TotalMnt             0.808514
# MntWines           NStorePurchases      0.804604
# Income             MntWines             0.781647
# MntMeatProducts    NStorePurchases      0.777546
# Income             MntMeatProducts      0.768042
#                    NCatalogPurchases    0.744149
# MntWines           NWebPurchases        0.741818
# Income             TotalPurchases       0.728849
# TotalMnt           NWebPurchases        0.727244
# MntMeatProducts    MntFishProducts      0.726708
# MntFruits          MntMeatProducts      0.714805
# NCatalogPurchases  NStorePurchases      0.709172
# MntFruits          MntFishProducts      0.708400
# MntFishProducts    MntSweetProducts     0.706352
# TotalMnt           PCatalogPurchases    0.701144
# MntMeatProducts    MntSweetProducts     0.700011
# dtype: float64

# %% [markdown]
# <br>
#
# The values reached through the spearman's correlation provide important information about some features, for instance:
#
# * The pairs MntMeatProducts and TotalMnt, MntWines and TotalMnt, are extremely highly correlated between each other. Those two pairs have the MntMeatProducts and MntWines, which are 'pieces of a whole', being that whole the TotalMnt, which implies that when a customer spends the most money in total, it also spends the most money in meat and wine.
# * The pair NCatalogPurchases and PCatalogPurchases, are also extremely highly correlated. This implies that when the number of catalog purchases increases, the amount of purchases using catalog instead of the other two channels, also increases.
# * The pair TotalMnt and TotalPurchases, has, once again, an extremly high correlation. This entails that when the total number of purchases increases, the total amount of money spent also increases, which it is quite straightforward.
# * There are a lot more pairs that are over the normal value of correlation, and therefore may create some redundancy in the model.
#
# The strong correlations described are not beneficial for the learning environment of the model, therefore, they will have to cease to exist. To achieve that, it will fist be studied the discrimination of the features, so that the least relevant ones can be discarded and the redundancy issues can be solved.

# %% [markdown]
# <br>

# %% [markdown]
# ### **6.** Exporting the dataset

# %% [markdown]
# In order to use this modified dataset in different notebooks, it is necessary to export it.
# The dataset is being exported in an excel format with the name "feature_extraction.xlsx".

# %%
data.to_excel( "feature_extract.xlsx")
